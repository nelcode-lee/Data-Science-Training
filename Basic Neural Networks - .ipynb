# %% [markdown]
# # Neural Netwrorks

# %% [markdown]
# ## Libraries

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ## Input Data for Training

# %%
observations = 1000

# %%
xs=np.random.uniform(low = -10, high = 10, size = (observations, 1))
zs=np.random.uniform( -10, 10, size = (observations, 1))
inputs = np.column_stack((xs,zs))
print(inputs.shape)
# Out:
# (1000, 2)

# %% [markdown]
# ## Targets

# %%
noise = np.random.uniform(-1,1, (observations, 1) )
targets = 2*xs - 3*zs + 5 + noise
print(targets.shape)
# Out:
# (1000, 1)

# %% [markdown]
# ## Plot The Traing Data

# %%
xs = xs.reshape(observations,)
zs = zs.reshape(observations,)
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(xs,zs,targets)
ax.set_xlabel('xs')
ax.set_ylabel('zs')
ax.set_zlabel('targets')
ax.view_init(azim=100)
plt.show()
targets = targets.reshape(observations,1)
xs = xs.reshape(observations,1)
zs = zs.reshape(observations,1)

# %% [markdown]
# ## Initialise variables

# %%
init_range = 0.1
weights = np.random.uniform(-init_range, init_range, size = (2,1))
biases=np.random.uniform(-init_range, init_range, size = (1))
print(weights)
print(biases)
# Out:
# [[0.0253723 ]
#  [0.08499579]]
# [-0.03911594]

# %% [markdown]
# ## Set the learning rate
# ### minimise the loss function to produce better NN

# %%
learning_rate = 0.02

# %% [markdown]
# ## Train the Model

# %%
for i in range(200):
    outputs= np.dot(inputs,weights)+ biases
    deltas = outputs-targets
    loss=np.sum(deltas **2)/2/observations

    print (loss)
    deltas_scaled = deltas / observations
    weights = weights -learning_rate * np.dot(inputs.T, deltas_scaled)     ### .T = transpose
    biases = biases- learning_rate *np.sum(deltas_scaled)
# Out:
# 0.38615009560946345
# 0.37722814334993154
# 0.36865940988007134
# 0.3604299113194783
# 0.3525262174075356
# 0.34493542958568457
# 0.3376451599474216
# 0.330643511021657
# 0.32391905635644463
# 0.3174608218714086
# 0.3112582679484136
# 0.30530127223127257
# 0.2995801131064023
# 0.2940854538374857
# 0.2888083273282357
# 0.28374012148840067
# 0.27887256517912573
# 0.2741977147147392
# 0.26970794089892697
# 0.26539591657414385
# 0.26125460466394657
# 0.2572772466887201
# 0.2534573517360743
# 0.24978868586789335
# 0.24626526194676363
# 0.24288132986516886
# 0.2396313671615112
# 0.23651007000764274
# 0.23351234455319939
# 0.23063329861260995
# 0.22786823368121736
# 0.225212637267479
# 0.22266217552873466
# 0.22021268619852397
# 0.2178601717939085
# 0.21560079309171715
# 0.21343086286306437
# 0.21134683985591915
# 0.2093453230159017
# 0.20742304593588046
# 0.20557687152530502
# 0.20380378689058365
# 0.20210089841814202
# 0.20046542705214562
# 0.1988947037591764
# 0.19738616517245897
# ...

# %%
print (weights, biases)
# Out:
# [[ 2.00366572]
#  [-3.00219077]] [5.0080579]

# %% [markdown]
# ### Bias improved with increased iterations

# %%
plt.plot(outputs, targets)
plt.xlabel('outputs')
plt.ylabel('targets')
plt.show()
